# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd 
import matplotlib.pylab as plt
import numpy as np
import scipy

# %% [markdown]
# A)

# %%
datos= [
    {'día':1,'IPMH':464},
    {'día':2,'IPMH':494},
    {'día':3,'IPMH':532},
    {'día':4,'IPMH':552},
    {'día':5,'IPMH':576},
    {'día':6,'IPMH':589}
]

# %%
df=pd.DataFrame(datos)
df
# Out:
#    día  IPMH
# 0    1   464
# 1    2   494
# 2    3   532
# 3    4   552
# 4    5   576
# 5    6   589

# %%
df1=pd.DataFrame(df["IPMH"]+-df["IPMH"]*2/1000)
df1
# Out:
#       IPMH
# 0  461.076
# 1  491.016
# 2  530.936
# 3  548.900
# 4  572.852
# 5  585.826
